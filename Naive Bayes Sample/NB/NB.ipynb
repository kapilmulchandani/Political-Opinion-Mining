# %%
# importing required libraries
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# %%
# read the train and test dataset
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test_labelled.csv')

# %%
# shape of the dataset
print('Shape of training data :',train_data.shape)
print('Shape of testing data :',test_data.shape)
# Out:
# ('Shape of training data :', (1599999, 6))
# ('Shape of testing data :', (500, 10))
# ('Shape of training data :', (1599999, 6))
# ('Shape of testing data :', (500, 10))

# %%
# Now, we need to predict the missing target variable in the test data
# target variable - Survived
#print(train_data)

# seperate the independent and target variable on training data
train_x = train_data.drop(train_data.columns[[0,2,3]], axis=1)

train_y = train_data[train_data.columns[[0]]]

print(train_x)
# Out:
#          1467810369  _TheSpecialOne_  \
# 0        1467810672    scotthamilton
# 1        1467810917         mattycus
# 2        1467811184          ElleCTF
# 3        1467811193           Karoli
# 4        1467811372         joy_wolf
# 5        1467811592          mybirch
# 6        1467811594             coZZ
# 7        1467811795  2Hood4Hollywood
# 8        1467812025          mimismo
# 9        1467812416   erinx3leannexo
# 10       1467812579     pardonlauren
# 11       1467812723             TLeC
# 12       1467812771  robrobbierobert
# 13       1467812784      bayofwolves
# 14       1467812799       HairByJess
# 15       1467812964   lovesongwriter
# 16       1467813137         armotley
# 17       1467813579       starkissed
# 18       1467813782        gi_gi_bee
# 19       1467813985           quanvu
# 20       1467813992       swinspeedx
# 21       1467814119        cooliodoc
# 22       1467814180       viJILLante
# 23       1467814192       Ljelli3166
# 24       1467814438    ChicagoCubbie
# 25       1467814783      KatieAngell
# 26       1467814883            gagoo
# 27       1467815199          abel209
# 28       1467815753  BaptisteTheFool
# 29       1467815923        fatkat309
# ...             ...              ...
# 1599969  2193578196    adbillingsley
# 1599970  2193578237           gekkko
# 1599971  2193578269       millerslab
# 1599972  2193578319  luckygeorgeblog
# 1599973  2193578345    Kristah_Diggs
# 1599974  2193578347        CoachChic
# 1599975  2193578348         serianna
# 1599976  2193578386   TeamUKskyvixen
# 1599977  2193578395      LaurenMoo10
# 1599978  2193578576    angel_sammy04
# 1599979  2193578679        puchal_ek
# 1599980  2193578716    youtubelatest
# 1599981  2193578739  Mandi_Davenport
# 1599982  2193578758         xoAurixo
# 1599983  2193578847       RobFoxKerr
# 1599984  2193578982         LISKFEST
# 1599985  2193579087          marhgil
# 1599986  2193579092        cathriiin
# 1599987  2193579191          tellman
# 1599988  2193579211        jazzstixx
# 1599989  2193579249    razzberry5594
# 1599990  2193579284        AgustinaP
# 1599991  2193579434    sdancingsteph
# 1599992  2193579477      ChloeAmisha
# 1599993  2193579489        EvolveTom
# 1599994  2193601966  AmandaMarie1028
# 1599995  2193601969      TheWDBoards
# 1599996  2193601991           bpbabe
# 1599997  2193602064     tinydiamondz
# 1599998  2193602129   RyanTrevMorris
#
#         @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# 0        is upset that he can't update his Facebook by ...
# 1        @Kenichan I dived many times for the ball. Man...
# 2          my whole body feels itchy and like its on fire
# 3        @nationwideclass no, it's not behaving at all....
# 4                            @Kwesidei not the whole crew
# 5                                              Need a hug
# 6        @LOLTrish hey  long time no see! Yes.. Rains a...
# 7                     @Tatiana_K nope they didn't have it
# 8                                @twittera que me muera ?
# 9              spring break in plain city... it's snowing
# 10                              I just re-pierced my ears
# 11       @caregiving I couldn't bear to watch it.  And ...
# 12       @octolinz16 It it counts, idk why I did either...
# 13       @smarrison i would've been the first, but i di...
# 14       @iamjazzyfizzle I wish I got to watch it with ...
# 15       Hollis' death scene will hurt me severely to w...
# 16                                    about to file taxes
# 17       @LettyA ahh ive always wanted to see rent  lov...
# 18       @FakerPattyPattz Oh dear. Were you drinking ou...
# 19       @alydesigns i was out most of the day so didn'...
# 20       one of my friend called me, and asked to meet ...
# 21        @angry_barista I baked you a cake but I ated it
# 22                  this week is not going as i had hoped
# 23                              blagh class at 8 tomorrow
# 24          I hate when I have to call and wake people up
# 25       Just going to cry myself to sleep after watchi...
# 26                                  im sad now  Miss.Lilly
# 27       ooooh.... LOL  that leslie.... and ok I won't ...
# 28       Meh... Almost Lover is the exception... this t...
# 29       some1 hacked my account on aim  now i have to ...
# ...                                                    ...
# 1599969  Thanks @eastwestchic &amp; @wangyip Thanks! Th...
# 1599970  @marttn thanks Martin. not the most imaginativ...
# 1599971          @MikeJonesPhoto Congrats Mike  Way to go!
# 1599972  http://twitpic.com/7jp4n - OMG! Office Space.....
# 1599973  @yrclndstnlvr ahaha nooo you were just away fr...
# 1599974  @BizCoachDeb  Hey, I'm baack! And, thanks so m...
# 1599975  @mattycus Yeah, my conscience would be clear i...
# 1599976  @MayorDorisWolfe Thats my girl - dishing out t...
# 1599977                          @shebbs123 i second that
# 1599978                                     In the garden
# 1599979  @myheartandmind jo jen by nemuselo zrovna té h...
# 1599980  Another Commenting Contest! [;: Yay!!!  http:/...
# 1599981  @thrillmesoon i figured out how to see my twee...
# 1599982  @oxhot theri tomorrow, drinking coffee, talkin...
# 1599983  You heard it here first -- We're having a girl...
# 1599984  if ur the lead singer in a band, beware fallin...
# 1599985              @tarayqueen too much ads on my blog.
# 1599986  @La_r_a NEVEER  I think that you both will get...
# 1599987  @Roy_Everitt ha- good job. that's right - we g...
# 1599988                 @Ms_Hip_Hop im glad ur doing well
# 1599989                              WOOOOO! Xbox is back
# 1599990  @rmedina @LaTati Mmmm  That sounds absolutely ...
# 1599991                  ReCoVeRiNg FrOm ThE lOnG wEeKeNd
# 1599992                                  @SCOOBY_GRITBOYS
# 1599993  @Cliff_Forster Yeah, that does work better tha...
# 1599994  Just woke up. Having no school is the best fee...
# 1599995  TheWDB.com - Very cool to hear old Walt interv...
# 1599996  Are you ready for your MoJo Makeover? Ask me f...
# 1599997  Happy 38th Birthday to my boo of alll time!!! ...
# 1599998  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1599999 rows x 3 columns]
#          1467810369  _TheSpecialOne_  \
# 0        1467810672    scotthamilton
# 1        1467810917         mattycus
# 2        1467811184          ElleCTF
# 3        1467811193           Karoli
# 4        1467811372         joy_wolf
# 5        1467811592          mybirch
# 6        1467811594             coZZ
# 7        1467811795  2Hood4Hollywood
# 8        1467812025          mimismo
# 9        1467812416   erinx3leannexo
# 10       1467812579     pardonlauren
# 11       1467812723             TLeC
# 12       1467812771  robrobbierobert
# 13       1467812784      bayofwolves
# 14       1467812799       HairByJess
# 15       1467812964   lovesongwriter
# 16       1467813137         armotley
# 17       1467813579       starkissed
# 18       1467813782        gi_gi_bee
# 19       1467813985           quanvu
# 20       1467813992       swinspeedx
# 21       1467814119        cooliodoc
# 22       1467814180       viJILLante
# 23       1467814192       Ljelli3166
# 24       1467814438    ChicagoCubbie
# 25       1467814783      KatieAngell
# 26       1467814883            gagoo
# 27       1467815199          abel209
# 28       1467815753  BaptisteTheFool
# 29       1467815923        fatkat309
# ...             ...              ...
# 1599969  2193578196    adbillingsley
# 1599970  2193578237           gekkko
# 1599971  2193578269       millerslab
# 1599972  2193578319  luckygeorgeblog
# 1599973  2193578345    Kristah_Diggs
# 1599974  2193578347        CoachChic
# 1599975  2193578348         serianna
# 1599976  2193578386   TeamUKskyvixen
# 1599977  2193578395      LaurenMoo10
# 1599978  2193578576    angel_sammy04
# 1599979  2193578679        puchal_ek
# 1599980  2193578716    youtubelatest
# 1599981  2193578739  Mandi_Davenport
# 1599982  2193578758         xoAurixo
# 1599983  2193578847       RobFoxKerr
# 1599984  2193578982         LISKFEST
# 1599985  2193579087          marhgil
# 1599986  2193579092        cathriiin
# 1599987  2193579191          tellman
# 1599988  2193579211        jazzstixx
# 1599989  2193579249    razzberry5594
# 1599990  2193579284        AgustinaP
# 1599991  2193579434    sdancingsteph
# 1599992  2193579477      ChloeAmisha
# 1599993  2193579489        EvolveTom
# 1599994  2193601966  AmandaMarie1028
# 1599995  2193601969      TheWDBoards
# 1599996  2193601991           bpbabe
# 1599997  2193602064     tinydiamondz
# 1599998  2193602129   RyanTrevMorris
#
#         @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# 0        is upset that he can't update his Facebook by ...
# 1        @Kenichan I dived many times for the ball. Man...
# 2          my whole body feels itchy and like its on fire
# 3        @nationwideclass no, it's not behaving at all....
# 4                            @Kwesidei not the whole crew
# 5                                              Need a hug
# 6        @LOLTrish hey  long time no see! Yes.. Rains a...
# 7                     @Tatiana_K nope they didn't have it
# 8                                @twittera que me muera ?
# 9              spring break in plain city... it's snowing
# 10                              I just re-pierced my ears
# 11       @caregiving I couldn't bear to watch it.  And ...
# 12       @octolinz16 It it counts, idk why I did either...
# 13       @smarrison i would've been the first, but i di...
# 14       @iamjazzyfizzle I wish I got to watch it with ...
# 15       Hollis' death scene will hurt me severely to w...
# 16                                    about to file taxes
# 17       @LettyA ahh ive always wanted to see rent  lov...
# 18       @FakerPattyPattz Oh dear. Were you drinking ou...
# 19       @alydesigns i was out most of the day so didn'...
# 20       one of my friend called me, and asked to meet ...
# 21        @angry_barista I baked you a cake but I ated it
# 22                  this week is not going as i had hoped
# 23                              blagh class at 8 tomorrow
# 24          I hate when I have to call and wake people up
# 25       Just going to cry myself to sleep after watchi...
# 26                                  im sad now  Miss.Lilly
# 27       ooooh.... LOL  that leslie.... and ok I won't ...
# 28       Meh... Almost Lover is the exception... this t...
# 29       some1 hacked my account on aim  now i have to ...
# ...                                                    ...
# 1599969  Thanks @eastwestchic &amp; @wangyip Thanks! Th...
# 1599970  @marttn thanks Martin. not the most imaginativ...
# 1599971          @MikeJonesPhoto Congrats Mike  Way to go!
# 1599972  http://twitpic.com/7jp4n - OMG! Office Space.....
# 1599973  @yrclndstnlvr ahaha nooo you were just away fr...
# 1599974  @BizCoachDeb  Hey, I'm baack! And, thanks so m...
# 1599975  @mattycus Yeah, my conscience would be clear i...
# 1599976  @MayorDorisWolfe Thats my girl - dishing out t...
# 1599977                          @shebbs123 i second that
# 1599978                                     In the garden
# 1599979  @myheartandmind jo jen by nemuselo zrovna té h...
# 1599980  Another Commenting Contest! [;: Yay!!!  http:/...
# 1599981  @thrillmesoon i figured out how to see my twee...
# 1599982  @oxhot theri tomorrow, drinking coffee, talkin...
# 1599983  You heard it here first -- We're having a girl...
# 1599984  if ur the lead singer in a band, beware fallin...
# 1599985              @tarayqueen too much ads on my blog.
# 1599986  @La_r_a NEVEER  I think that you both will get...
# 1599987  @Roy_Everitt ha- good job. that's right - we g...
# 1599988                 @Ms_Hip_Hop im glad ur doing well
# 1599989                              WOOOOO! Xbox is back
# 1599990  @rmedina @LaTati Mmmm  That sounds absolutely ...
# 1599991                  ReCoVeRiNg FrOm ThE lOnG wEeKeNd
# 1599992                                  @SCOOBY_GRITBOYS
# 1599993  @Cliff_Forster Yeah, that does work better tha...
# 1599994  Just woke up. Having no school is the best fee...
# 1599995  TheWDB.com - Very cool to hear old Walt interv...
# 1599996  Are you ready for your MoJo Makeover? Ask me f...
# 1599997  Happy 38th Birthday to my boo of alll time!!! ...
# 1599998  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1599999 rows x 3 columns]

# %%
# seperate the independent and target variable on testing data
test_x = test_data.drop(test_data.columns[[0]], axis=1)
print(test_x)
test_y = test_data[test_data.columns[[2]]]
type(test_y)
test_y = test_y.fillna(0)


#print(test_y)
# Out:
#      Unnamed: 0.1  sentiment                                          query  \
# 0           14702        4.0                bernie sanders -filter:retweets
# 1           23345        0.0                bernie sanders -filter:retweets
# 2           21568        4.0                bernie sanders -filter:retweets
# 3           60529        4.0                bernie sanders -filter:retweets
# 4           54214        4.0                bernie sanders -filter:retweets
# 5            6703        0.0                bernie sanders -filter:retweets
# 6           63209        4.0                bernie sanders -filter:retweets
# 7           41509        4.0                bernie sanders -filter:retweets
# 8           22826        4.0                bernie sanders -filter:retweets
# 9             954        4.0                bernie sanders -filter:retweets
# 10          38811        0.0                bernie sanders -filter:retweets
# 11          48691        4.0                bernie sanders -filter:retweets
# 12          49310        4.0                bernie sanders -filter:retweets
# 13          33001        4.0                bernie sanders -filter:retweets
# 14          37657        4.0                bernie sanders -filter:retweets
# 15           2904        0.0                bernie sanders -filter:retweets
# 16          20557        4.0                bernie sanders -filter:retweets
# 17          28924        NaN                bernie sanders -filter:retweets
# 18          45700        4.0                bernie sanders -filter:retweets
# 19          20683        4.0                bernie sanders -filter:retweets
# 20          16411        NaN              elizabeth warren -filter:retweets
# 21          39059        NaN              elizabeth warren -filter:retweets
# 22          52120        0.0              elizabeth warren -filter:retweets
# 23          27697        4.0              elizabeth warren -filter:retweets
# 24           8224        NaN              elizabeth warren -filter:retweets
# 25          17546        4.0              elizabeth warren -filter:retweets
# 26           7811        0.0              elizabeth warren -filter:retweets
# 27          47115        4.0              elizabeth warren -filter:retweets
# 28          33264        0.0              elizabeth warren -filter:retweets
# 29          21326        4.0              elizabeth warren -filter:retweets
# ..            ...        ...                                            ...
# 470         47664        0.0  pete buttigieg OR mayor pete -filter:retweets
# 471         74161        0.0  pete buttigieg OR mayor pete -filter:retweets
# 472         49058        0.0  pete buttigieg OR mayor pete -filter:retweets
# 473         12295        0.0  pete buttigieg OR mayor pete -filter:retweets
# 474         29648        4.0  pete buttigieg OR mayor pete -filter:retweets
# 475         11541        NaN  pete buttigieg OR mayor pete -filter:retweets
# 476         61757        4.0  pete buttigieg OR mayor pete -filter:retweets
# 477         53252        4.0  pete buttigieg OR mayor pete -filter:retweets
# 478         11675        4.0  pete buttigieg OR mayor pete -filter:retweets
# 479         49302        0.0  pete buttigieg OR mayor pete -filter:retweets
# 480          2328        4.0                 kamala harris -filter:retweets
# 481          1666        0.0                 kamala harris -filter:retweets
# 482          9950        0.0                 kamala harris -filter:retweets
# 483         29369        4.0                 kamala harris -filter:retweets
# 484         18837        0.0                 kamala harris -filter:retweets
# 485         19655        0.0                 kamala harris -filter:retweets
# 486          8487        NaN                 kamala harris -filter:retweets
# 487         27049        4.0                 kamala harris -filter:retweets
# 488          8778        4.0                 kamala harris -filter:retweets
# 489         33044        0.0                 kamala harris -filter:retweets
# 490          1464        4.0                 kamala harris -filter:retweets
# 491         30773        4.0                 kamala harris -filter:retweets
# 492         20741        NaN                 kamala harris -filter:retweets
# 493          1114        0.0                 kamala harris -filter:retweets
# 494         14622        0.0                 kamala harris -filter:retweets
# 495         23666        4.0                 kamala harris -filter:retweets
# 496         20210        0.0                 kamala harris -filter:retweets
# 497           186        4.0                 kamala harris -filter:retweets
# 498         12264        4.0                 kamala harris -filter:retweets
# 499         29499        4.0                 kamala harris -filter:retweets
#
#                       id                 date             user  location  \
# 0    1195891288236871681   2019-11-17 2:27:56   sierra_rebecca       NaN
# 1    1195170879870840832   2019-11-15 2:45:17         DavidHHI       NaN
# 2    1195363683364409345  2019-11-15 15:31:25        EricJafMN       NaN
# 3    1197740859573383168   2019-11-22 4:57:28    evilberniefan       NaN
# 4    1197175768771633152  2019-11-20 15:32:00    MichaelJFoody       NaN
# 5    1196535484685664258  2019-11-18 21:07:44       JamianNace       NaN
# 6    1197610226238799877  2019-11-21 20:18:23      comradelean       NaN
# 7    1193957261711986690  2019-11-11 18:22:48     darryladams_       NaN
# 8    1195203754506604544   2019-11-15 4:55:55       Lyme300000       NaN
# 9    1196973274565136384   2019-11-20 2:07:22      makeusmiles       NaN
# 10   1194077870169247749   2019-11-12 2:22:03      dallas_waid       NaN
# 11   1197353755592863744   2019-11-21 3:19:15  PoliticsTBTimes       NaN
# 12   1197348841747468289   2019-11-21 2:59:44    fightBackAnon       NaN
# 13   1194437810503274496   2019-11-13 2:12:20     vaneitaadams       NaN
# 14   1194171695826817024   2019-11-12 8:34:53  StephenWAbbott1       NaN
# 15   1196845181364031489  2019-11-19 17:38:22         sanrous2       NaN
# 16   1195422863056093189  2019-11-15 19:26:35         Lyn1Marc       NaN
# 17   1194756900983697408  2019-11-13 23:20:17      SDSA4Bernie       NaN
# 18   1197412336019148800   2019-11-21 7:12:02    Wonderbitch82       NaN
# 19   1195415144727302145  2019-11-15 18:55:54     jbenmenachem       NaN
# 20   1195442469036531712  2019-11-15 20:44:29     YahooFinance       NaN
# 21   1197368633472585729   2019-11-21 4:18:22    cowboywinders       NaN
# 22   1197624121091334145  2019-11-21 21:13:35    Jerry65826489       NaN
# 23   1194459653876408320   2019-11-13 3:39:08          Ah_Clem       NaN
# 24   1196192679761235968  2019-11-17 22:25:33     CannefaxJane       NaN
# 25   1195380328522608640  2019-11-15 16:37:34       QuorumCall       NaN
# 26   1196232180952813569   2019-11-18 1:02:31   DisappeariodDX       NaN
# 27   1197997874409291777  2019-11-22 21:58:45      ChuckWatts2       NaN
# 28   1194059280074379265   2019-11-12 1:08:11   KentuckyKennyZ       NaN
# 29   1195053904737656832  2019-11-14 19:00:28      NVforWarren       NaN
# ..                   ...                  ...              ...       ...
# 470  1197541785997914117  2019-11-21 15:46:25         julito77       NaN
# 471  1197777935350075398   2019-11-22 7:24:48  olivia__william       NaN
# 472  1197506636958466049  2019-11-21 13:26:45   ChancesMom2018       NaN
# 473  1196560188670648320  2019-11-18 22:45:54   blackonionking       NaN
# 474  1195709899268857856  2019-11-16 14:27:09       MitchGayns       NaN
# 475  1196581716955058176   2019-11-19 0:11:27      jdzlindeed2       NaN
# 476  1197338944247083009   2019-11-21 2:20:24      LukewSavage       NaN
# 477  1197374778190921728   2019-11-21 4:42:47        PlanetPOV       NaN
# 478  1196577545023557633  2019-11-18 23:54:52  nicksgoodtweets       NaN
# 479  1197500873859108865  2019-11-21 13:03:51      astrodrew15       NaN
# 480  1196522903178825728  2019-11-18 20:17:45        powers_lp       NaN
# 481  1196622211718819841   2019-11-19 2:52:22       splurtatta       NaN
# 482  1195198698067763200   2019-11-15 4:35:49        Rdkill762       NaN
# 483  1198036124498743297   2019-11-23 0:30:45  siliconvalleyex       NaN
# 484  1197482582507581440  2019-11-21 11:51:10  christianllamar       NaN
# 485  1197414625232510976   2019-11-21 7:21:08    atlas_chugged       NaN
# 486  1195539886498971650   2019-11-16 3:11:35     BitterSestak       NaN
# 487  1197337321852604417   2019-11-21 2:13:57       EmmaKinery       NaN
# 488  1195488002539163651  2019-11-15 23:45:25           tm_roy       NaN
# 489  1197599338467405824  2019-11-21 19:35:07    CylantJustice       NaN
# 490  1196664574327578624   2019-11-19 5:40:42  Quintus74689745       NaN
# 491  1197860675340656640  2019-11-22 12:53:34         Praisedc       NaN
# 492  1197381571600367616   2019-11-21 5:09:47    BreitbartNews       NaN
# 493  1196814150544117762  2019-11-19 15:35:03        blaze0497       NaN
# 494  1194235515685478402  2019-11-12 12:48:29    cathycarrgcac       NaN
# 495  1197357890589229058   2019-11-21 3:35:41            Mkm45       NaN
# 496  1197392210439876608   2019-11-21 5:52:04     PittsburghPG       NaN
# 497  1197019268258435074   2019-11-20 5:10:07   Ravenswood2016       NaN
# 498  1194701573928169473  2019-11-13 19:40:26  shoutgracegrace       NaN
# 499  1198018463563997184  2019-11-22 23:20:34   Summer_Reignzz       NaN
#
#                        user_loc  \
# 0              Grand Rapids, MI
# 1                       HHI, SC
# 2         Saint Paul, Minnesota
# 3                           NaN
# 4     District of Columbia, USA
# 5               New Jersey, USA
# 6         atlanta, ga | she/her
# 7                 Manhattan, NY
# 8                           NaN
# 9                North Carolina
# 10                          NaN
# 11           Tampa Bay, Florida
# 12              Washington, USA
# 13                  Atlanta, IN
# 14                          NaN
# 15                United States
# 16                           SC
# 17                  Seattle, WA
# 18                   Newark, NJ
# 19                 New York, NY
# 20                 New York, NY
# 21                Oklahoma, USA
# 22                          NaN
# 23         Roxbury, Boston, USA
# 24                          NaN
# 25                          USA
# 26       San Francisco, CA, USA
# 27               Wilmington, OH
# 28                          NaN
# 29                       Nevada
# ..                          ...
# 470           Boston and Harlem
# 471                   h🤟🏾town
# 472                         NaN
# 473                         NaN
# 474             Boston, MA 🇺🇸
# 475                         NaN
# 476            Toronto, Ontario
# 477             Los Angeles, CA
# 478                        hell
# 479                         NaN
# 480                         NaN
# 481                    St. Paul
# 482                 McHenry, IL
# 483              Santa Cruz, Ca
# 484                Arizona, USA
# 485                         NaN
# 486                         NaN
# 487              Washington, DC
# 488    NW Edge of MSP Metro, MN
# 489               Where needed.
# 490                         NaN
# 491               Washington DC
# 492                         NaN
# 493               Kentucky, USA
# 494                Texas Austin
# 495                         USA
# 496             Pittsburgh, Pa.
# 497             New Orleans, LA
# 498                Granbury, TX
# 499  Sea of Cocoa-Caramel-Honey
#
#                                                   text
# 0    If you call Bernie Sanders a commie, I'm proba...
# 1    Venezuelan Assemblyman: I Suggest Bernie Sande...
# 2    @daveweigel @cascamike @nytimes Bernie Sanders...
# 3    Last night my white male friends and I smoked ...
# 4    When Bernie Sanders is president PBS will be t...
# 5    @Daly81 Wow. Had no idea. Between that and wan...
# 6    BERNIE! MOTHERFUCKING! SANDERS! MY HERO! MY PR...
# 7    Bernie Sanders and Joe Biden are the only boom...
# 8    @cdaragones @otterpode @UTLAnow Not someone li...
# 9       Omg matty just said vote for Bernie Sanders I-
# 10   @reyansh_aarav @woodenbee @AOC Until people lo...
# 11   Sen. Bernie Sanders urgently addressed climate...
# 12   Bernie Sanders is the only right answer for ou...
# 13   Fighting antisemitism is at the heart of the l...
# 14   @FemaleBernieBro Feel the Bern, Blessed Bee an...
# 15   ILHAN OMAR -WHILE ENDORSING BERNIE SANDERS.  C...
# 16   @HillaryClinton I remember when you intimidate...
# 17   We'll be canvassing at South Seattle College t...
# 18        Like Bernie Sanders. https://t.co/qXRpBKMn37
# 19   .@JonathanCohn: "@DataProgress recently polled...
# 20   Elizabeth Warren unshackles herself from 'Medi...
# 21   Elizabeth Warren: aight imma get outta here ht...
# 22   @ProudResister Lol this is 100% Elizabeth Warr...
# 23   A Facebook Bigwig Runs a Personal News Site Wi...
# 24        @ewarren Elizabeth Warren...you too are not.
# 25   Elizabeth Warren Vows to Expand Health Coverag...
# 26   @AlytaDeLeon Dead giveaway about how Native Am...
# 27   It would seem that Mayor Pete has pissed off p...
# 28   ...just realized that Elizabeth Warren and Hil...
# 29   I’m caucusing for Elizabeth Warren because und...
# ..                                                 ...
# 470  @Connie50474231 The campaign contacts me regul...
# 471  Let’s just say my thoughts on Pete buttigieg r...
# 472  @BillKristol Pete Buttigieg is 37 and has NEVE...
# 473  I forced a robot to listen to the desires of 1...
# 474  @nkem This my top 3...  1.Bernie 2. Mayor Pete...
# 475  Well, what will they say about the Morehouse M...
# 476  I see Pete Buttigieg is continuing his strateg...
# 477  Order of Dems praised tonight on MSNBC post- d...
# 478  gonna start ironically doing The Mayor Pete an...
# 479  Since this didn’t really come up at the debate...
# 480  @JohnJHarwood @CapehartJ I can not get over Ka...
# 481  @JoyAnnReid @CapehartJ I mean let's get real t...
# 482  Author EXPOSES Kamala Harris'  troubling recor...
# 483  All in for Kamala Harris. https://t.co/J97vOeD5mF
# 484  Kamala Harris is not African American.  Kamala...
# 485  @MattSteinhaus @KyleKulinski There is no coher...
# 486  @CNN Former President was talking to Kamala Ha...
# 487  Kamala Harris opens with: “First of all we hav...
# 488  Yes, we do. And we need someone who can ruthle...
# 489  By the way, Kamala Harris is laughing because ...
# 490  @14thstreetblues Kamala is from the Bay Area. ...
# 491  Pastor Who Prayed For Obama In 2008 Election L...
# 492        Talk about a gaffe! https://t.co/Wzb6IEd8Wk
# 493  BREAKING: Kamala Harris Attacked At Live Event...
# 494  Kamala Harris's has gotten rid of a lot of evi...
# 495  Kamala Harris is doing very well tonight. "Sho...
# 496  Kamala Harris calls out Tulsi Gabbard after he...
# 497  @MattZemek @MattZeitlin @latimes Wow! That was...
# 498  Kamala Harris Motions The Crowd To Give Her A ...
# 499  Trump, Ivanka donated to Kamala Harris campaig...
#
# [500 rows x 9 columns]
#      Unnamed: 0.1  sentiment                                          query  \
# 0           14702        4.0                bernie sanders -filter:retweets
# 1           23345        0.0                bernie sanders -filter:retweets
# 2           21568        4.0                bernie sanders -filter:retweets
# 3           60529        4.0                bernie sanders -filter:retweets
# 4           54214        4.0                bernie sanders -filter:retweets
# 5            6703        0.0                bernie sanders -filter:retweets
# 6           63209        4.0                bernie sanders -filter:retweets
# 7           41509        4.0                bernie sanders -filter:retweets
# 8           22826        4.0                bernie sanders -filter:retweets
# 9             954        4.0                bernie sanders -filter:retweets
# 10          38811        0.0                bernie sanders -filter:retweets
# 11          48691        4.0                bernie sanders -filter:retweets
# 12          49310        4.0                bernie sanders -filter:retweets
# 13          33001        4.0                bernie sanders -filter:retweets
# 14          37657        4.0                bernie sanders -filter:retweets
# 15           2904        0.0                bernie sanders -filter:retweets
# 16          20557        4.0                bernie sanders -filter:retweets
# 17          28924        NaN                bernie sanders -filter:retweets
# 18          45700        4.0                bernie sanders -filter:retweets
# 19          20683        4.0                bernie sanders -filter:retweets
# 20          16411        NaN              elizabeth warren -filter:retweets
# 21          39059        NaN              elizabeth warren -filter:retweets
# 22          52120        0.0              elizabeth warren -filter:retweets
# 23          27697        4.0              elizabeth warren -filter:retweets
# 24           8224        NaN              elizabeth warren -filter:retweets
# 25          17546        4.0              elizabeth warren -filter:retweets
# 26           7811        0.0              elizabeth warren -filter:retweets
# 27          47115        4.0              elizabeth warren -filter:retweets
# 28          33264        0.0              elizabeth warren -filter:retweets
# 29          21326        4.0              elizabeth warren -filter:retweets
# ..            ...        ...                                            ...
# 470         47664        0.0  pete buttigieg OR mayor pete -filter:retweets
# 471         74161        0.0  pete buttigieg OR mayor pete -filter:retweets
# 472         49058        0.0  pete buttigieg OR mayor pete -filter:retweets
# 473         12295        0.0  pete buttigieg OR mayor pete -filter:retweets
# 474         29648        4.0  pete buttigieg OR mayor pete -filter:retweets
# 475         11541        NaN  pete buttigieg OR mayor pete -filter:retweets
# 476         61757        4.0  pete buttigieg OR mayor pete -filter:retweets
# 477         53252        4.0  pete buttigieg OR mayor pete -filter:retweets
# 478         11675        4.0  pete buttigieg OR mayor pete -filter:retweets
# 479         49302        0.0  pete buttigieg OR mayor pete -filter:retweets
# 480          2328        4.0                 kamala harris -filter:retweets
# 481          1666        0.0                 kamala harris -filter:retweets
# 482          9950        0.0                 kamala harris -filter:retweets
# 483         29369        4.0                 kamala harris -filter:retweets
# 484         18837        0.0                 kamala harris -filter:retweets
# 485         19655        0.0                 kamala harris -filter:retweets
# 486          8487        NaN                 kamala harris -filter:retweets
# 487         27049        4.0                 kamala harris -filter:retweets
# 488          8778        4.0                 kamala harris -filter:retweets
# 489         33044        0.0                 kamala harris -filter:retweets
# 490          1464        4.0                 kamala harris -filter:retweets
# 491         30773        4.0                 kamala harris -filter:retweets
# 492         20741        NaN                 kamala harris -filter:retweets
# 493          1114        0.0                 kamala harris -filter:retweets
# 494         14622        0.0                 kamala harris -filter:retweets
# 495         23666        4.0                 kamala harris -filter:retweets
# 496         20210        0.0                 kamala harris -filter:retweets
# 497           186        4.0                 kamala harris -filter:retweets
# 498         12264        4.0                 kamala harris -filter:retweets
# 499         29499        4.0                 kamala harris -filter:retweets
#
#                       id                 date             user  location  \
# 0    1195891288236871681   2019-11-17 2:27:56   sierra_rebecca       NaN
# 1    1195170879870840832   2019-11-15 2:45:17         DavidHHI       NaN
# 2    1195363683364409345  2019-11-15 15:31:25        EricJafMN       NaN
# 3    1197740859573383168   2019-11-22 4:57:28    evilberniefan       NaN
# 4    1197175768771633152  2019-11-20 15:32:00    MichaelJFoody       NaN
# 5    1196535484685664258  2019-11-18 21:07:44       JamianNace       NaN
# 6    1197610226238799877  2019-11-21 20:18:23      comradelean       NaN
# 7    1193957261711986690  2019-11-11 18:22:48     darryladams_       NaN
# 8    1195203754506604544   2019-11-15 4:55:55       Lyme300000       NaN
# 9    1196973274565136384   2019-11-20 2:07:22      makeusmiles       NaN
# 10   1194077870169247749   2019-11-12 2:22:03      dallas_waid       NaN
# 11   1197353755592863744   2019-11-21 3:19:15  PoliticsTBTimes       NaN
# 12   1197348841747468289   2019-11-21 2:59:44    fightBackAnon       NaN
# 13   1194437810503274496   2019-11-13 2:12:20     vaneitaadams       NaN
# 14   1194171695826817024   2019-11-12 8:34:53  StephenWAbbott1       NaN
# 15   1196845181364031489  2019-11-19 17:38:22         sanrous2       NaN
# 16   1195422863056093189  2019-11-15 19:26:35         Lyn1Marc       NaN
# 17   1194756900983697408  2019-11-13 23:20:17      SDSA4Bernie       NaN
# 18   1197412336019148800   2019-11-21 7:12:02    Wonderbitch82       NaN
# 19   1195415144727302145  2019-11-15 18:55:54     jbenmenachem       NaN
# 20   1195442469036531712  2019-11-15 20:44:29     YahooFinance       NaN
# 21   1197368633472585729   2019-11-21 4:18:22    cowboywinders       NaN
# 22   1197624121091334145  2019-11-21 21:13:35    Jerry65826489       NaN
# 23   1194459653876408320   2019-11-13 3:39:08          Ah_Clem       NaN
# 24   1196192679761235968  2019-11-17 22:25:33     CannefaxJane       NaN
# 25   1195380328522608640  2019-11-15 16:37:34       QuorumCall       NaN
# 26   1196232180952813569   2019-11-18 1:02:31   DisappeariodDX       NaN
# 27   1197997874409291777  2019-11-22 21:58:45      ChuckWatts2       NaN
# 28   1194059280074379265   2019-11-12 1:08:11   KentuckyKennyZ       NaN
# 29   1195053904737656832  2019-11-14 19:00:28      NVforWarren       NaN
# ..                   ...                  ...              ...       ...
# 470  1197541785997914117  2019-11-21 15:46:25         julito77       NaN
# 471  1197777935350075398   2019-11-22 7:24:48  olivia__william       NaN
# 472  1197506636958466049  2019-11-21 13:26:45   ChancesMom2018       NaN
# 473  1196560188670648320  2019-11-18 22:45:54   blackonionking       NaN
# 474  1195709899268857856  2019-11-16 14:27:09       MitchGayns       NaN
# 475  1196581716955058176   2019-11-19 0:11:27      jdzlindeed2       NaN
# 476  1197338944247083009   2019-11-21 2:20:24      LukewSavage       NaN
# 477  1197374778190921728   2019-11-21 4:42:47        PlanetPOV       NaN
# 478  1196577545023557633  2019-11-18 23:54:52  nicksgoodtweets       NaN
# 479  1197500873859108865  2019-11-21 13:03:51      astrodrew15       NaN
# 480  1196522903178825728  2019-11-18 20:17:45        powers_lp       NaN
# 481  1196622211718819841   2019-11-19 2:52:22       splurtatta       NaN
# 482  1195198698067763200   2019-11-15 4:35:49        Rdkill762       NaN
# 483  1198036124498743297   2019-11-23 0:30:45  siliconvalleyex       NaN
# 484  1197482582507581440  2019-11-21 11:51:10  christianllamar       NaN
# 485  1197414625232510976   2019-11-21 7:21:08    atlas_chugged       NaN
# 486  1195539886498971650   2019-11-16 3:11:35     BitterSestak       NaN
# 487  1197337321852604417   2019-11-21 2:13:57       EmmaKinery       NaN
# 488  1195488002539163651  2019-11-15 23:45:25           tm_roy       NaN
# 489  1197599338467405824  2019-11-21 19:35:07    CylantJustice       NaN
# 490  1196664574327578624   2019-11-19 5:40:42  Quintus74689745       NaN
# 491  1197860675340656640  2019-11-22 12:53:34         Praisedc       NaN
# 492  1197381571600367616   2019-11-21 5:09:47    BreitbartNews       NaN
# 493  1196814150544117762  2019-11-19 15:35:03        blaze0497       NaN
# 494  1194235515685478402  2019-11-12 12:48:29    cathycarrgcac       NaN
# 495  1197357890589229058   2019-11-21 3:35:41            Mkm45       NaN
# 496  1197392210439876608   2019-11-21 5:52:04     PittsburghPG       NaN
# 497  1197019268258435074   2019-11-20 5:10:07   Ravenswood2016       NaN
# 498  1194701573928169473  2019-11-13 19:40:26  shoutgracegrace       NaN
# 499  1198018463563997184  2019-11-22 23:20:34   Summer_Reignzz       NaN
#
#                        user_loc  \
# 0              Grand Rapids, MI
# 1                       HHI, SC
# 2         Saint Paul, Minnesota
# 3                           NaN
# 4     District of Columbia, USA
# 5               New Jersey, USA
# 6         atlanta, ga | she/her
# 7                 Manhattan, NY
# 8                           NaN
# 9                North Carolina
# 10                          NaN
# 11           Tampa Bay, Florida
# 12              Washington, USA
# 13                  Atlanta, IN
# 14                          NaN
# 15                United States
# 16                           SC
# 17                  Seattle, WA
# 18                   Newark, NJ
# 19                 New York, NY
# 20                 New York, NY
# 21                Oklahoma, USA
# 22                          NaN
# 23         Roxbury, Boston, USA
# 24                          NaN
# 25                          USA
# 26       San Francisco, CA, USA
# 27               Wilmington, OH
# 28                          NaN
# 29                       Nevada
# ..                          ...
# 470           Boston and Harlem
# 471                   h🤟🏾town
# 472                         NaN
# 473                         NaN
# 474             Boston, MA 🇺🇸
# 475                         NaN
# 476            Toronto, Ontario
# 477             Los Angeles, CA
# 478                        hell
# 479                         NaN
# 480                         NaN
# 481                    St. Paul
# 482                 McHenry, IL
# 483              Santa Cruz, Ca
# 484                Arizona, USA
# 485                         NaN
# 486                         NaN
# 487              Washington, DC
# 488    NW Edge of MSP Metro, MN
# 489               Where needed.
# 490                         NaN
# 491               Washington DC
# 492                         NaN
# 493               Kentucky, USA
# 494                Texas Austin
# 495                         USA
# 496             Pittsburgh, Pa.
# 497             New Orleans, LA
# 498                Granbury, TX
# 499  Sea of Cocoa-Caramel-Honey
#
#                                                   text
# 0    If you call Bernie Sanders a commie, I'm proba...
# 1    Venezuelan Assemblyman: I Suggest Bernie Sande...
# 2    @daveweigel @cascamike @nytimes Bernie Sanders...
# 3    Last night my white male friends and I smoked ...
# 4    When Bernie Sanders is president PBS will be t...
# 5    @Daly81 Wow. Had no idea. Between that and wan...
# 6    BERNIE! MOTHERFUCKING! SANDERS! MY HERO! MY PR...
# 7    Bernie Sanders and Joe Biden are the only boom...
# 8    @cdaragones @otterpode @UTLAnow Not someone li...
# 9       Omg matty just said vote for Bernie Sanders I-
# 10   @reyansh_aarav @woodenbee @AOC Until people lo...
# 11   Sen. Bernie Sanders urgently addressed climate...
# 12   Bernie Sanders is the only right answer for ou...
# 13   Fighting antisemitism is at the heart of the l...
# 14   @FemaleBernieBro Feel the Bern, Blessed Bee an...
# 15   ILHAN OMAR -WHILE ENDORSING BERNIE SANDERS.  C...
# 16   @HillaryClinton I remember when you intimidate...
# 17   We'll be canvassing at South Seattle College t...
# 18        Like Bernie Sanders. https://t.co/qXRpBKMn37
# 19   .@JonathanCohn: "@DataProgress recently polled...
# 20   Elizabeth Warren unshackles herself from 'Medi...
# 21   Elizabeth Warren: aight imma get outta here ht...
# 22   @ProudResister Lol this is 100% Elizabeth Warr...
# 23   A Facebook Bigwig Runs a Personal News Site Wi...
# 24        @ewarren Elizabeth Warren...you too are not.
# 25   Elizabeth Warren Vows to Expand Health Coverag...
# 26   @AlytaDeLeon Dead giveaway about how Native Am...
# 27   It would seem that Mayor Pete has pissed off p...
# 28   ...just realized that Elizabeth Warren and Hil...
# 29   I’m caucusing for Elizabeth Warren because und...
# ..                                                 ...
# 470  @Connie50474231 The campaign contacts me regul...
# 471  Let’s just say my thoughts on Pete buttigieg r...
# 472  @BillKristol Pete Buttigieg is 37 and has NEVE...
# 473  I forced a robot to listen to the desires of 1...
# 474  @nkem This my top 3...  1.Bernie 2. Mayor Pete...
# 475  Well, what will they say about the Morehouse M...
# 476  I see Pete Buttigieg is continuing his strateg...
# 477  Order of Dems praised tonight on MSNBC post- d...
# 478  gonna start ironically doing The Mayor Pete an...
# 479  Since this didn’t really come up at the debate...
# 480  @JohnJHarwood @CapehartJ I can not get over Ka...
# 481  @JoyAnnReid @CapehartJ I mean let's get real t...
# 482  Author EXPOSES Kamala Harris'  troubling recor...
# 483  All in for Kamala Harris. https://t.co/J97vOeD5mF
# 484  Kamala Harris is not African American.  Kamala...
# 485  @MattSteinhaus @KyleKulinski There is no coher...
# 486  @CNN Former President was talking to Kamala Ha...
# 487  Kamala Harris opens with: “First of all we hav...
# 488  Yes, we do. And we need someone who can ruthle...
# 489  By the way, Kamala Harris is laughing because ...
# 490  @14thstreetblues Kamala is from the Bay Area. ...
# 491  Pastor Who Prayed For Obama In 2008 Election L...
# 492        Talk about a gaffe! https://t.co/Wzb6IEd8Wk
# 493  BREAKING: Kamala Harris Attacked At Live Event...
# 494  Kamala Harris's has gotten rid of a lot of evi...
# 495  Kamala Harris is doing very well tonight. "Sho...
# 496  Kamala Harris calls out Tulsi Gabbard after he...
# 497  @MattZemek @MattZeitlin @latimes Wow! That was...
# 498  Kamala Harris Motions The Crowd To Give Her A ...
# 499  Trump, Ivanka donated to Kamala Harris campaig...
#
# [500 rows x 9 columns]

# %%
'''
Create the object of the Naive Bayes model
You can also add other parameters and test your code here
Some parameters are : var_smoothing
Documentation of sklearn GaussianNB: 

https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html

 '''
model = GaussianNB()
#train_x = train_x.reshape(1,-1)
#train_y = train_y.reshape(1,-1)


# fit the model with the training data
model.fit(train_x,train_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-410959dfa0d4> in <module>()
#      14
#      15 # fit the model with the training data
# ---> 16 model.fit(train_x,train_y)
#
# //anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.pyc in fit(self, X, y, sample_weight)
#     188         self : object
#     189         """
# --> 190         X, y = check_X_y(X, y)
#     191         return self._partial_fit(X, y, np.unique(y), _refit=True,
#     192                                  sample_weight=sample_weight)
#
# //anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# //anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     565         # make sure we actually converted to numeric:
#     566         if dtype_numeric and array.dtype.kind == "O":
# --> 567             array = array.astype(np.float64)
#     568         if not allow_nd and array.ndim >= 3:
#     569             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-410959dfa0d4> in <module>()
#      14
#      15 # fit the model with the training data
# ---> 16 model.fit(train_x,train_y)
#
# //anaconda2/lib/python2.7/site-packages/sklearn/naive_bayes.pyc in fit(self, X, y, sample_weight)
#     188         self : object
#     189         """
# --> 190         X, y = check_X_y(X, y)
#     191         return self._partial_fit(X, y, np.unique(y), _refit=True,
#     192                                  sample_weight=sample_weight)
#
# //anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# //anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     565         # make sure we actually converted to numeric:
#     566         if dtype_numeric and array.dtype.kind == "O":
# --> 567             array = array.astype(np.float64)
#     568         if not allow_nd and array.ndim >= 3:
#     569             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!

# %%
# predict the target on the train dataset
predict_train = model.predict(train_x)
print('Target on train data',predict_train)

# %%
# Accuray Score on train dataset
accuracy_train = accuracy_score(train_y,predict_train)
print('accuracy_score on train dataset : ', accuracy_train)

# %%
# predict the target on the test dataset
predict_test = model.predict(test_x)
print('Target on test data',predict_test)

# %%
# Accuracy Score on test dataset
accuracy_test = accuracy_score(test_y,predict_test)
print('accuracy_score on test dataset : ', accuracy_test)
